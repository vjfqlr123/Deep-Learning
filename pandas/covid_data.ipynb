# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_html('https://www.busan.go.kr/covid19/Corona19.do')

# %%
data
# Out:
# [   지역  중구   서구   동구  영도구  부산진구  동래구   남구   북구  해운대구  사하구  금정구  강서구  연제구  수영구  \
#  0  금일   -    -    -    2     6    3    -    -     5    4    3    1    -    1
#  1  누적  71  234  136  216   480  345  285  227   380  494  229  146  240  173
#
#     사상구 기장군   기타
#  0    6   -    2
#  1  269  97  702  ,
#     지역  중구   서구   동구  영도구  부산진구  동래구   남구   북구  해운대구  사하구  금정구  강서구  연제구  수영구  \
#  0  금일   -    -    -    2     6    3    -    -     5    4    3    1    -    1
#  1  누적  71  234  136  216   480  345  285  227   380  494  229  146  240  173
#
#     사상구 기장군   기타
#  0    6   -    2
#  1  269  97  702  ,
#     지역  중구   서구   동구  영도구  부산진구  동래구   남구   북구  해운대구  사하구  금정구  강서구  연제구  수영구  \
#  0  금일   -    -    -    2     6    3    -    -     5    4    3    1    -    1
#  1  누적  71  234  136  216   480  345  285  227   380  494  229  146  240  173
#
#     사상구 기장군   기타
#  0    6   -    2
#  1  269  97  702  ,
#      시도   시구군  장소유형          상호명  \
#  0   부산    북구   음식점        경동영양탕
# ...

# %%
df = data[3]
df
# Out:
#     시도   시구군  장소유형          상호명  \
# 0   부산    북구   음식점        경동영양탕
# 1   부산   사상구   음식점        하동재첩국
# 2   부산    중구   pc방   쓰리팝pc cafe
# 3   부산  부산진구   목욕탕      백천탕(남탕)
# 4   부산   사하구    택시          NaN
# ..  ..   ...   ...          ...
# 57  부산   NaN    택시          NaN
# 58  부산  부산진구  단란주점       태양노래주점
# 59  부산  부산진구    택시           택시
# 60  부산   기장군   미용실         쉬즈헤어
# 61  부산   사하구    기타  바른법연구원 사하지사
#
#                                             주소(도로명주소)  \
# 0                              북구 낙동대로 1776번길 72(구포동)
# 1                                사상구 가야대로 290-12(주례동)
# 2                             중구 비프광장로 28, 2층(남포동 5가)
# 3                                      부산진구 동평로95번길 4
# 4   신평시장 인근-> 사하구 선별진료소 앞(하신번영로127) 사하구 선별진료소앞(하신번...
# ..                                                ...
# 57                                  서구 충무동 사거리->서구보건소
# 58                            부산진구 서면문화로 6, 지하1층(부전동)
# 59                              범내골 지하철역 -> 당평초등학교 인근
# ...

# %%
df.values
# Out:
# array([['부산', '북구', '음식점', '경동영양탕', '북구 낙동대로 1776번길 72(구포동)',
#         '2021.4.10.(토) 10:59~11:35북구보건소 상담바람', '소독완료'],
#        ['부산', '사상구', '음식점', '하동재첩국', '사상구 가야대로 290-12(주례동)',
#         '2021.04.13(화) 11:53-12:07', '소독완료'],
#        ['부산', '중구', 'pc방', '쓰리팝pc cafe', '중구 비프광장로 28, 2층(남포동 5가)',
#         '2021.04.10(금) 12:40-22:21', '소독완료'],
#        ['부산', '부산진구', '목욕탕', '백천탕(남탕)', '부산진구 동평로95번길 4',
#         '2021.04.10(토) 10:37-12:45', '소독완료'],
#        ['부산', '사하구', '택시', nan,
#         '신평시장 인근-> 사하구 선별진료소 앞(하신번영로127) 사하구 선별진료소앞(하신번영로127)-> 신평시장 인근',
#         '2021.04.16(금) 15:10-15:202021.04.16(금) 15:45-16:00', nan],
#        ['부산', '부산진구', '기원', '푸른기원', '부산진구 서면로 71, 4층(부전동)',
#         '2021.4.6(화)-4.13(화) 11:00-22:00', '소독완료'],
#        ['부산', '부산진구', '택시', '부산37바6698', nan, '2021.04.12(월)-4.17(토)',
#         '소독완료'],
#        ['부산', '사하구', '팬시점', '해피버스데이', '사하구 낙동대로516번길 33',
#         '4.13(화) 17:00-21:004.14(수) 17:00-21:00', '소독완료'],
# ...
