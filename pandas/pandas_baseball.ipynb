# %%
import numpy as np
import pandas as pd

# %% [markdown]
# conda install xlrd - xlrd 모듈이 없다고 나오면 설치합시다. 엑셀관련 모듈입니다.

# %%
baseball = pd.read_excel("./data/2019_baseball_hitter20.xlsx",  sheet_name=0)
baseball
# Out:
#     순번     이름   팀명     타율  경기수   타수   안타  2루타  3루타  홈런   타점   득점  도루  볼넷   삼진  \
# 0    1    양의지   NC  0.354  118  390  138   26    0  20   68   61   4  48   43
# 1    2  페르난데스   두산  0.344  144  572  197   34    0  15   88   87   1  61   54
# 2    3    박민우   NC  0.344  125  468  161   23    8   1   45   89  18  41   40
# 3    4    이정후   키움  0.336  140  574  193   31   10   6   68   91  13  45   40
# 4    5    강백호   KT  0.336  116  438  147   29    1  13   65   72   9  61   87
# 5    6    고종욱   SK  0.323  137  492  159   25    7   3   56   76  31  18   89
# 6    7    로하스   KT  0.322  142  521  168   30    3  24  104   68   4  49  120
# 7    8    박건우   두산  0.319  127  458  146   27    5  10   64   83  12  60   57
# 8    9    유한준   KT  0.317  139  501  159   19    1  14   86   61   3  52   61
# 9   10    채은성   LG  0.315  128  470  148   18    1  12   72   59   2  24   67
# 10  11    이천웅   LG  0.308  138  546  168   24    3   2   48   88  21  57   82
# ...

# %%
baseball.head()
# Out:
#    순번     이름  팀명     타율  경기수   타수   안타  2루타  3루타  홈런  타점  득점  도루  볼넷  삼진  \
# 0   1    양의지  NC  0.354  118  390  138   26    0  20  68  61   4  48  43
# 1   2  페르난데스  두산  0.344  144  572  197   34    0  15  88  87   1  61  54
# 2   3    박민우  NC  0.344  125  468  161   23    8   1  45  89  18  41  40
# 3   4    이정후  키움  0.336  140  574  193   31   10   6  68  91  13  45  40
# 4   5    강백호  KT  0.336  116  438  147   29    1  13  65  72   9  61  87
#
#      출루율    장타율
# 0  0.438  0.574
# 1  0.409  0.483
# 2  0.403  0.434
# 3  0.386  0.456
# 4  0.416  0.495

# %%
data1 = baseball.sort_values(by=["홈런"], ascending=False)
data1.head()
# Out:
#     순번    이름  팀명     타율  경기수   타수   안타  2루타  3루타  홈런   타점   득점  도루  볼넷   삼진  \
# 13  14    샌즈  키움  0.305  139  525  160   39    1  28  113  100   1  77  101
# 6    7   로하스  KT  0.322  142  521  168   30    3  24  104   68   4  49  120
# 15  16   전준우  롯데  0.301  141  545  164   30    1  22   83   85   8  46   71
# 0    1   양의지  NC  0.354  118  390  138   26    0  20   68   61   4  48   43
# 11  12   김하성  키움  0.307  139  540  166   38    2  19  104  112  33  70   80
#
#       출루율    장타율
# 13  0.396  0.543
# 6   0.381  0.530
# 15  0.359  0.481
# 0   0.438  0.574
# 11  0.389  0.491

# %%
#컬럼 중 순번 삭제
del data1['순번']

# %%
data1
# Out:
#        이름   팀명     타율  경기수   타수   안타  2루타  3루타  홈런   타점   득점  도루  볼넷   삼진  \
# 13     샌즈   키움  0.305  139  525  160   39    1  28  113  100   1  77  101
# 6     로하스   KT  0.322  142  521  168   30    3  24  104   68   4  49  120
# 15    전준우   롯데  0.301  141  545  164   30    1  22   83   85   8  46   71
# 0     양의지   NC  0.354  118  390  138   26    0  20   68   61   4  48   43
# 11    김하성   키움  0.307  139  540  166   38    2  19  104  112  33  70   80
# 17    최형우  KIA  0.300  136  456  137   31    1  17   86   65   0  85   77
# 1   페르난데스   두산  0.344  144  572  197   34    0  15   88   87   1  61   54
# 8     유한준   KT  0.317  139  501  159   19    1  14   86   61   3  52   61
# 4     강백호   KT  0.336  116  438  147   29    1  13   65   72   9  61   87
# 9     채은성   LG  0.315  128  470  148   18    1  12   72   59   2  24   67
# 14    김현수   LG  0.304  140  526  160   37    0  11   82   75   3  54   52
# 19    손아섭   롯데  0.295  134  512  151   22    1  10   63   78  13  52   92
# ...

# %%
data1.reset_index(drop=True, inplace=True)
data1
# Out:
#        이름   팀명     타율  경기수   타수   안타  2루타  3루타  홈런   타점   득점  도루  볼넷   삼진  \
# 0      샌즈   키움  0.305  139  525  160   39    1  28  113  100   1  77  101
# 1     로하스   KT  0.322  142  521  168   30    3  24  104   68   4  49  120
# 2     전준우   롯데  0.301  141  545  164   30    1  22   83   85   8  46   71
# 3     양의지   NC  0.354  118  390  138   26    0  20   68   61   4  48   43
# 4     김하성   키움  0.307  139  540  166   38    2  19  104  112  33  70   80
# 5     최형우  KIA  0.300  136  456  137   31    1  17   86   65   0  85   77
# 6   페르난데스   두산  0.344  144  572  197   34    0  15   88   87   1  61   54
# 7     유한준   KT  0.317  139  501  159   19    1  14   86   61   3  52   61
# 8     강백호   KT  0.336  116  438  147   29    1  13   65   72   9  61   87
# 9     채은성   LG  0.315  128  470  148   18    1  12   72   59   2  24   67
# 10    김현수   LG  0.304  140  526  160   37    0  11   82   75   3  54   52
# 11    손아섭   롯데  0.295  134  512  151   22    1  10   63   78  13  52   92
# ...

# %%
data1[['이름', '홈런']].head()
# Out:
#      이름  홈런
# 0    샌즈  28
# 1   로하스  24
# 2   전준우  22
# 3   양의지  20
# 4   김하성  19

# %%
data1[2:5]
# Out:
#      이름  팀명     타율  경기수   타수   안타  2루타  3루타  홈런   타점   득점  도루  볼넷  삼진    출루율  \
# 2   전준우  롯데  0.301  141  545  164   30    1  22   83   85   8  46  71  0.359
# 3   양의지  NC  0.354  118  390  138   26    0  20   68   61   4  48  43  0.438
# 4   김하성  키움  0.307  139  540  166   38    2  19  104  112  33  70  80  0.389
#
#      장타율
# 2  0.481
# 3  0.574
# 4  0.491

# %%
data1.loc[:, ['이름', '홈런','경기수','타율', '삼진']]
# Out:
#        이름  홈런  경기수     타율   삼진
# 0      샌즈  28  139  0.305  101
# 1     로하스  24  142  0.322  120
# 2     전준우  22  141  0.301   71
# 3     양의지  20  118  0.354   43
# 4     김하성  19  139  0.307   80
# 5     최형우  17  136  0.300   77
# 6   페르난데스  15  144  0.344   54
# 7     유한준  14  139  0.317   61
# 8     강백호  13  116  0.336   87
# 9     채은성  12  128  0.315   67
# 10    김현수  11  140  0.304   52
# 11    손아섭  10  134  0.295   92
# 12    박건우  10  127  0.319   57
# 13    김태균   6  127  0.305   94
# 14    이정후   6  140  0.336   40
# 15    김헌곤   5  114  0.297   41
# 16    고종욱   3  137  0.323   89
# 17    서건창   2  113  0.300   50
# 18    이천웅   2  138  0.308   82
# 19    박민우   1  125  0.344   40

# %%
import matplotlib.pyplot as plt

# %%
#코드에 한글이 들어가는 것은 일반적으로 좋지 않습니다.
#단, 데이터분석에 한해서는 동작에 오류가 적고 직관적인 인식 및 코드수정에 유용하여 권장하지 않지만 금지하지 않습니다.
data1.이름
# Out:
# 0        샌즈
# 1       로하스
# 2       전준우
# 3       양의지
# 4       김하성
# 5       최형우
# 6     페르난데스
# 7       유한준
# 8       강백호
# 9       채은성
# 10      김현수
# 11      손아섭
# 12      박건우
# 13      김태균
# 14      이정후
# 15      김헌곤
# 16      고종욱
# 17      서건창
# 18      이천웅
# 19      박민우
# Name: 이름, dtype: object

# %%
#원하는 형태로 가공하기 위해 데이터의 타입을 변환해야 합니다.
name = data1.이름.tolist()  #파이썬의 리스트 타입으로 만들어주는 함수
name
# Out:
# ['\xa0샌즈',
#  '\xa0로하스',
#  '\xa0전준우',
#  '양의지',
#  '\xa0김하성',
#  '\xa0최형우',
#  '페르난데스',
#  '\xa0유한준',
#  '\xa0강백호',
#  '\xa0채은성',
#  '\xa0김현수',
#  '\xa0손아섭',
#  '\xa0박건우',
#  '\xa0김태균',
#  '\xa0이정후',
#  '\xa0김헌곤',
#  '\xa0고종욱',
#  '\xa0서건창',
#  '\xa0이천웅',
#  '\xa0박민우']

# %%
#잡음발생!!! 데이터의 첫자리에 공백이 삽입됨 제거를 합시다.
#데이터 정제
name2=[]  # 빈 변수를 생성
for i in name:
    name2.append(i.strip()) #좌우공백제거

name2
# Out:
# ['샌즈',
#  '로하스',
#  '전준우',
#  '양의지',
#  '김하성',
#  '최형우',
#  '페르난데스',
#  '유한준',
#  '강백호',
#  '채은성',
#  '김현수',
#  '손아섭',
#  '박건우',
#  '김태균',
#  '이정후',
#  '김헌곤',
#  '고종욱',
#  '서건창',
#  '이천웅',
#  '박민우']

# %%
#데이터프레임소스 값 변경
data1.이름 = name2
#data1.이름    #타입의 모양을 테스트해 보세요.
data1.이름.tolist()
# Out:
# ['샌즈',
#  '로하스',
#  '전준우',
#  '양의지',
#  '김하성',
#  '최형우',
#  '페르난데스',
#  '유한준',
#  '강백호',
#  '채은성',
#  '김현수',
#  '손아섭',
#  '박건우',
#  '김태균',
#  '이정후',
#  '김헌곤',
#  '고종욱',
#  '서건창',
#  '이천웅',
#  '박민우']

# %%
hr = data1.홈런.tolist()
hr
# Out:
# [28, 24, 22, 20, 19, 17, 15, 14, 13, 12, 11, 10, 10, 6, 6, 5, 3, 2, 2, 1]

# %% [markdown]
# matplotlib를 이용하여 차트 그림. matplotlib는 한글 사용X 한글사용시 약간의 커스텀마이징이 필요

# %%
#plt.figure(figsize=(10,4))
#plt.plot(name, hr)
#plt.show()

#주석제거시 실행해보세요. 한글이 깨어집니다.

# %%
import matplotlib.font_manager as fm
import platform

if platform.system() =='Windows':
    font_path = 'C:/Windows/Fonts/gulim.ttc' #윈도우 굴림폰트
elif platform.system() == 'Linux':    #우분투 18.04 테스트됨, 나눔폰트 설치 후
    font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
    
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rcParams['font.family'] = font_name
plt.rcParams['font.size'] = 12

# %%
plt.figure(figsize=(10,4))
plt.plot(name, hr)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.plot(name, hr)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.bar(name, hr, color='#0000ff')
plt.xlabel('선수이름')
plt.xticks(rotation=45)
plt.ylabel('홈런수')
plt.title('2018년 프로야구 홈런타자 순위')
plt.show()

# %%
plt.figure(figsize=(14,4))
plt.bar(name, hr, color='#0000ff')
plt.xlabel('선수이름')
plt.xticks(rotation=45)
plt.ylabel('홈런수')
plt.title('2018년 프로야구 홈런타자 순위')
plt.show()

# %%
plt.figure(figsize=(14,4))
plt.bar(name, hr, color='#0000ff')
plt.xlabel('선수이름')
plt.xticks(rotation=10)
plt.ylabel('홈런수')
plt.title('2018년 프로야구 홈런타자 순위')
plt.show()

# %%
plt.figure(figsize=(12,12))
plt.pie(hr, labels=name, autopct='%1.2f %%', shadow=False, startangle=-20)
plt.title('2018년 프로야구 홈런타자 순위')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(hr, labels=name, autopct='%1.2f %%', shadow=False, startangle=0)
plt.title('2018년 프로야구 홈런타자 순위')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(hr, labels=name, autopct='%1.2f %%', shadow=False, startangle=-20)
plt.title('2018년 프로야구 홈런타자 순위')
plt.show()

# %%
import seaborn as sns
 
sns.set(style="darkgrid")

# %%
#다시 한글설정 모듈을 삽입합니다.

import matplotlib.font_manager as fm
import platform

if platform.system() =='Windows':
    font_path = 'C:/Windows/Fonts/gulim.ttc' #윈도우 굴림폰트
elif platform.system() == 'Linux':    #우분투 18.04 테스트됨, 나눔폰트 설치 후
    font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
    
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rcParams['font.family'] = font_name
plt.rcParams['font.size'] = 12

# %%
#seaborn
plt.figure(figsize=(15,4))
chart = sns.barplot(x="이름", y="홈런", data=data1) #seaborn은 데이터프레임을 직접 다루는 함수가 많습니다.
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.show()
